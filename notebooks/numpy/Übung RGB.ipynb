# %%
# ein paar Importe für diese Übung
import numpy as np
from scipy.cluster.vq import kmeans2
import matplotlib.pyplot as plt
import matplotlib.image as img
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Übung RGB
#
# Gegeben sind die RGB-Daten eines Bildes:

# %%
rgb_data = img.imread('example_figures/facing_python.jpg')

# TODO: geben Sie die Dimensionen dieses Arrays uas

# %% [markdown]
# 1) Zeigen Sie das Bild an (Tipp: `plt.imshow`). Zeigen Sie außerdem den Rot-, Grün- und Blaukanal des Bildes an.

# %%
# TODO Bild anzeigen...

# TODO Rot/Grün/Blaukanal separat anzeigen

# %% [markdown]
# 2) Rechnen Sie das Bild in Graustufen um, indem Sie den Mittelwert aus Rot-, Blau- und Grün-Anteil ausrechnen.

# %%
# Bild als Graustufen anzeigen...

# %% [markdown]
# 3 ) Erzeugen Sie ein Array `flat_data`, welches alle RGP-Triplets enthält, aber keine Informationen mehr über die Koordinaten der Pixel (Tipp: `reshape`).

# %%
# Farbwerte als Array (x, 3) oder (3, x)
# flat_data = ...

# %% [markdown]
# 4) Erzeugen Sie je ein Histogram für den roten, blauen und grünen Farbkanal (analog zum Beispielbild) - Tipp: `plt.hist`
# ![rgb_histograms.png](attachment:rgb_histograms.png)

# %%
# histogramme erzeugen

# %% [markdown]
# 5) Erzeugen Sie einen 3D-Scatterplot mit den Farbdaten - die drei Achsen sind dabei der Rot-, Grün-, und Blau-Wert. Jeder hunderste Pixel soll dabei in seiner tatsächlichen Farbe in dem Scatterplot eingetragen werden.

# %%
fig3 = plt.figure()
ax = Axes3D(fig3)

# ax.scatter ...

# %% [markdown]
# 6) Nutzen Sie die Funktion `kmeans2`, um die Farbdaten in 5 Cluster zu gruppieren. Zeichnen Sie die Zentren der gefundenen Cluster in den Scatterplot. Dokumentation zu `kmeans2`: https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.vq.kmeans2.html

# %%
# TODO 
# res = kmeans2(...)

# %% [markdown]
# 7) Reduzieren Sie das ursprüngliche Bild auf 5 Farben, indem Sie jeden Pixel durch die Farbe des naheliegensten Clusterzentrums ersetzen. Tipp: Wenn Sie alle Rückgabewerte der `kmeans2`-Funktion nutzen, reicht dies aus, um das Bild zu erzeugen. Untersuchen Sie also zunächst die Rückgabewerte der `kmeans2`-Funktion, z.B. indem Sie die Shapes ausgeben.

# %%
# TODO reduzierte Pixel berechnen

# %% [markdown]
# 8) Plotten Sie das resultierende Bild mit `imshow`. Dazu müssen Sie Ihre umgerechneten Pixel wieder in die Form (`reshape`) des Bildes bringen.

# %%
# TODO Bild plotten
